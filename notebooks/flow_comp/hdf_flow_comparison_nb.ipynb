# %% [markdown]
# # HDF Reference Line Flow Comparison

# %% [markdown]
# __Contributors__: Marissela Gomez (marissela.gomez@stantec.com), Nada Elgamal (nada.elgamal@stantec.com)
# __Last updated__: 3/20/2026

# %%
import hdf_flow_comparison_functions as hf

# %% [markdown]
# First review the reference line flow in the p.hdf file,
# then the input flow from the dss hydrograph in the Hydrology folder
# once both are read, compare:
# * The peak flow
# * Time of peak flow
# * Export an interactive graph of the ref line flow and junction flow into folder for the model (should be easy to navigate between them both) X-axis time stamp, Y-axis cfs
# --- (if interactable, such as html, that would be nice. Otherwise just a static image is fine)
# * Table per HUC10 with the following columns:
#     * Event Name #from the .p text file
#     * Plan number #when first reading the .hdf, grab the plan number
#     * Junction name #(should match REF name as well) #grabbing the reference line first from the p.##.hdf
#     * Peak Flow (experienced ref line)
#     * Time of Peak Flow (experienced ref line)
#     * Peak Flow (expected junction flow)
#     * Time of Peak Flow (expected junction flow)
#     * Difference in Peak Flow #Experience - expected
#     * Difference in Time of Peak Flow #Experience - expected
#
#
# __Folder structure__: The output folder is created 2 folders above the input folder in "References" > [huc 10] > output files. It doesn't matter where the code folder lives, output folder is determined using input folder.

# %%
## User inputs and working directories
inputs_filepath = r"C:\Users\magomez\OneDrive - Stantec\_Projects\2026\Local_files_Big_Horn\review\pre_cross_bc_check\1008001006\1008001006"

# %%
def main():
    # Get HUC10 from folder name
    huc10 = hf.get_huc_name(inputs_filepath)
    print(f"Reading HUC10 {huc10}...")

    # Create output folder if it doesn't exist
    outputs_filepath = hf.create_output_dir(inputs_filepath)

    # Get list of hdf files
    hdf_files_list = hf.get_hdf_files_with_ext(inputs_filepath)

    # List the hdf files with existing reference lines
    plans_w_ref_list = hf.check_for_ref_lines_in_hdfs(hdf_files_list, outputs_filepath)

    # Generate reference vs junction line plots for each plan and create summary table for entire model
    hf.create_plots_and_table(inputs_filepath, outputs_filepath, huc10, plans_w_ref_list)

    return

if __name__ == "__main__":
    main()
# Out:
# Reading HUC10 1008001006...
# 	Outputs filepath: C:\Users\magomez\OneDrive - Stantec\_Projects\2026\Local_files_Big_Horn\review\pre_cross_bc_check\References\1008001006
# Checking hdf files for reference lines...
# 	0 plans with reference lines. List exported as a .txt file in C:\Users\magomez\OneDrive - Stantec\_Projects\2026\Local_files_Big_Horn\review\pre_cross_bc_check\References\1008001006\Plans_with_reference_lines.txt
# 	0 plans without reference lines.List exported as a .txt file in C:\Users\magomez\OneDrive - Stantec\_Projects\2026\Local_files_Big_Horn\review\pre_cross_bc_check\References\1008001006\Plans_without_reference_lines.txt
# 	No plans with reference lines found in C:\Users\magomez\OneDrive - Stantec\_Projects\2026\Local_files_Big_Horn\review\pre_cross_bc_check\1008001006\1008001006

# %% [markdown]
# # FIN
